# %% [markdown]
# #PROJECT

# %%
import json
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
url = "https://api.tfl.gov.uk/AccidentStats/2019" 
response = requests.get(url)

data = response.json()
df = pd.json_normalize(data)

df.to_csv('incidenti_tfl_2019.csv', index=False)

# %%
df.head()
# Out:
#                                                $type      id        lat  \
# 0  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345979  51.570865
# 1  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345980  51.603859
# 2  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345981  51.512198
# 3  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345982  51.431480
# 4  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345983  51.473487
#
#         lon                                           location  \
# 0 -0.231959  On Edgware Road Near The Junction With north C...
# 1 -0.187240     On Willow Way Near The Junction With Long Lane
# 2 -0.153122  On north Audley Street Near The Junction With ...
# 3 -0.016083  On Bromley Road Near The Junction With Daneswo...
# 4  0.145202  On Belmont Road Near The Junction With Bedonwe...
#
#                    date severity              borough  \
# 0  2019-01-04T21:22:00Z   Slight               Barnet
# 1  2019-01-04T23:33:00Z   Slight               Barnet
# 2  2019-01-04T22:15:00Z   Slight  City of Westminster
# 3  2019-01-04T18:00:00Z   Slight             Lewisham
# 4  2019-01-04T20:45:00Z   Slight               Bexley
#
#                                           casualties  \
# 0  [{'$type': 'Tfl.Api.Presentation.Entities.Acci...
# 1  [{'$type': 'Tfl.Api.Presentation.Entities.Acci...
# 2  [{'$type': 'Tfl.Api.Presentation.Entities.Acci...
# 3  [{'$type': 'Tfl.Api.Presentation.Entities.Acci...
# 4  [{'$type': 'Tfl.Api.Presentation.Entities.Acci...
#
#                                             vehicles
# 0  [{'$type': 'Tfl.Api.Presentation.Entities.Acci...
# 1  [{'$type': 'Tfl.Api.Presentation.Entities.Acci...
# 2  [{'$type': 'Tfl.Api.Presentation.Entities.Acci...
# 3  [{'$type': 'Tfl.Api.Presentation.Entities.Acci...
# 4  [{'$type': 'Tfl.Api.Presentation.Entities.Acci...

# %%
df.describe()
# Out:
#                   id           lat           lon
# count   50626.000000  50626.000000  50626.000000
# mean   544054.000000     51.509198     -0.118897
# std    185715.647807      0.067383      0.141133
# min    345828.000000     51.295233     -0.509795
# 25%    358484.250000     51.468225     -0.200805
# 50%    544054.000000     51.514006     -0.114336
# 75%    729623.750000     51.553555     -0.035484
# max    742280.000000     51.691126      0.307909

# %%
df_vehicles = df.copy()

if df_vehicles['vehicles'].isnull().any():
    print("Warning: Missing or invalid data detected in 'vehicles'. Dropping null values.")
    df_vehicles = df_vehicles.dropna(subset=['vehicles'])

df_vehicles = df_vehicles.explode('vehicles')

df_vehicles.drop(columns=['lat', 'lon', 'date', 'location', 'severity', 'borough', 'casualties'], inplace=True)

df_vehicles_normalized = pd.json_normalize(df_vehicles['vehicles'].values)

if '$type' in df_vehicles_normalized.columns:
    df_vehicles_normalized.drop(columns=['$type'], inplace=True)

df_vehicles = df_vehicles.reset_index(drop=True).join(df_vehicles_normalized)

df_vehicles.drop(columns=['vehicles'], inplace=True)

print("Normalized and processed vehicle data:\n", df_vehicles.head(30))
# Out:
#                                                 $type      id  \
# 0   Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345979
# 1   Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345979
# 2   Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345980
# 3   Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345980
# 4   Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345980
# 5   Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345981
# 6   Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345982
# 7   Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345982
# 8   Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345983
# 9   Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345983
# 10  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345984
# 11  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345984
# 12  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345985
# 13  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345985
# 14  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345986
# 15  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345986
# 16  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345987
# 17  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345987
# 18  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345988
# 19  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345988
# 20  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345989
# 21  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345989
# 22  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345990
# 23  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345991
# 24  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345991
# 25  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345992
# 26  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345992
# 27  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345992
# 28  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345992
# 29  Tfl.Api.Presentation.Entities.AccidentStats.Ac...  345993
#
#                      type
# 0   Motorcycle_500cc_Plus
# 1                     Car
# 2     Motorcycle_50_125cc
# 3                     Car
# 4                     Car
# 5                     Car
# 6     Motorcycle_50_125cc
# 7                     Car
# 8                     Car
# 9                     Car
# 10                    Car
# 11                    Car
# 12    Motorcycle_50_125cc
# 13                    Car
# 14                    Car
# 15                    Car
# 16                    Car
# 17                    Car
# 18             PedalCycle
# 19                   Taxi
# 20                    Car
# 21                    Car
# 22                   Taxi
# 23             PedalCycle
# 24                    Car
# 25                    Car
# 26                    Car
# 27                    Car
# 28                    Car
# 29             PedalCycle

# %%
grouped_accidents = df_vehicles.groupby('id')['type'].apply(list).reset_index()

grouped_accidents['unique_vehicle_types'] = grouped_accidents['type'].apply(lambda x: list(set(x)))

grouped_accidents['mixed_vehicles'] = grouped_accidents['unique_vehicle_types'].apply(lambda x: len(x) > 1)

grouped_accidents.columns = ['id', 'vehicles_in_accident', 'unique_vehicle_types', 'mixed_vehicles']
grouped_accidents.head(30)
# Out:
#         id          vehicles_in_accident          unique_vehicle_types  \
# 0   345828                    [Car, Car]                         [Car]
# 1   345829                    [Car, Car]                         [Car]
# 2   345830             [PedalCycle, Car]             [Car, PedalCycle]
# 3   345831                         [Car]                         [Car]
# 4   345832                    [Car, Car]                         [Car]
# 5   345833                    [Car, Car]                         [Car]
# 6   345834                         [Car]                         [Car]
# 7   345835              [Car, Car, Taxi]                   [Car, Taxi]
# 8   345836                    [Car, Car]                         [Car]
# 9   345837              [Car, Car, Taxi]                   [Car, Taxi]
# 10  345838                         [Car]                         [Car]
# 11  345839           [LightGoodsVehicle]           [LightGoodsVehicle]
# 12  345840                        [Taxi]                        [Taxi]
# 13  345841                    [Car, Car]                         [Car]
# 14  345842              [Car, Car, Taxi]                   [Car, Taxi]
# 15  345843                         [Car]                         [Car]
# 16  345844   [Motorcycle_125_500cc, Car]   [Car, Motorcycle_125_500cc]
# 17  345845                    [Car, Car]                         [Car]
# 18  345846                   [Car, Taxi]                   [Car, Taxi]
# 19  345847                    [Car, Car]                         [Car]
# 20  345848             [PedalCycle, Car]             [Car, PedalCycle]
# 21  345849    [Motorcycle_50_125cc, Car]    [Motorcycle_50_125cc, Car]
# 22  345850         [Motorcycle_50_125cc]         [Motorcycle_50_125cc]
# 23  345851             [Car, BusOrCoach]             [Car, BusOrCoach]
# 24  345852                    [Car, Car]                         [Car]
# 25  345853   [Motorcycle_125_500cc, Car]   [Car, Motorcycle_125_500cc]
# 26  345854  [Motorcycle_500cc_Plus, Car]  [Car, Motorcycle_500cc_Plus]
# 27  345855             [PedalCycle, Car]             [Car, PedalCycle]
# 28  345856  [Motorcycle_500cc_Plus, Car]  [Car, Motorcycle_500cc_Plus]
# 29  345857                    [Car, Car]                         [Car]
#
#     mixed_vehicles
# 0            False
# 1            False
# 2             True
# 3            False
# 4            False
# 5            False
# 6            False
# 7             True
# 8            False
# 9             True
# 10           False
# 11           False
# 12           False
# 13           False
# 14            True
# 15           False
# 16            True
# 17           False
# 18            True
# 19           False
# 20            True
# 21            True
# 22           False
# 23            True
# 24           False
# 25            True
# 26            True
# 27            True
# 28            True
# 29           False

# %%
# Count rows with mixed vehicles (True)
num_mixed_vehicles = grouped_accidents['mixed_vehicles'].sum()

# Display the result
print(f"Number of accidents involving multiple vehicle types: {num_mixed_vehicles}")
# Out:
# Number of accidents involving multiple vehicle types: 0

# %%
df_vehicles = df_vehicles.groupby(['id']).agg({'type': lambda x: list(x)}).reset_index()
df_vehicles['num_vehicles'] = df_vehicles['type'].apply(lambda x: len(x))
df_vehicles
# Out:
#            id                      type  num_vehicles
# 0      345828                [Car, Car]             2
# 1      345829                [Car, Car]             2
# 2      345830                [Car, Car]             2
# 3      345831                     [Car]             1
# 4      345832  [PedalCycle, PedalCycle]             2
# ...       ...                       ...           ...
# 50621  742276              [PedalCycle]             1
# 50622  742277                     [Car]             1
# 50623  742278  [PedalCycle, PedalCycle]             2
# 50624  742279              [Taxi, Taxi]             2
# 50625  742280                [Car, Car]             2
#
# [50626 rows x 3 columns]

# %%
df['borough'].unique()
# Out:
# array(['City of Westminster', 'Lambeth', 'Camden', 'Brent', 'Newham',
#        'Croydon', 'Southwark', 'Barking and Dagenham', 'Merton',
#        'Redbridge', 'Tower Hamlets', 'Islington',
#        'Kensington and Chelsea', 'Ealing', 'Hounslow', 'Haringey',
#        'Wandsworth', 'Hillingdon', 'Lewisham', 'Waltham Forest',
#        'Hammersmith and Fulham', 'Enfield', 'Bromley', 'Bexley', 'Harrow',
#        'Hackney', 'Greenwich', 'Barnet', 'Kingston',
#        'Richmond upon Thames', 'Havering', 'Sutton', 'City of London'],
#       dtype=object)

# %%
null_data = df[df.isnull().any(axis=1)]
print(null_data)
# Out:
# Empty DataFrame
# Columns: [id, lat, lon, location, date, severity, borough, casualties, vehicles]
# Index: []

# %%
print(len(data))
exmpl = {
    "$type": "Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities",
    "id": 345979,
    "lat": 51.570865,
    "lon": -0.231959,
    "location": "On Edgware Road Near The Junction With north Circular Road",
    "date": "2019-01-04T21:22:00Z",
    "severity": "Slight",
    "borough": "Barnet",
    "casualties": [{
        "$type": "Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities",
        "age": 20,
        "class": "Driver",
        "severity": "Slight",
        "mode": "PoweredTwoWheeler",
        "ageBand": "Adult"
    }],
    "vehicles": [{
        "$type": "Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities",
        "type": "Motorcycle_500cc_Plus"
    }, {
        "$type": "Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities",
        "type": "Car"
    }]
}
# Out:
# 50626

# %%
df_vehicles.head(30)
# Out:
#         id                                          type  num_vehicles
# 0   345828                                    [Car, Car]             2
# 1   345829                                    [Car, Car]             2
# 2   345830                                    [Car, Car]             2
# 3   345831                                         [Car]             1
# 4   345832                      [PedalCycle, PedalCycle]             2
# 5   345833                                    [Car, Car]             2
# 6   345834                                         [Car]             1
# 7   345835                               [Car, Car, Car]             3
# 8   345836                                    [Car, Car]             2
# 9   345837                               [Car, Car, Car]             3
# 10  345838                                         [Car]             1
# 11  345839                                         [Car]             1
# 12  345840                                         [Car]             1
# 13  345841                                    [Car, Car]             2
# 14  345842                            [Taxi, Taxi, Taxi]             3
# 15  345843                                         [Car]             1
# 16  345844                                    [Car, Car]             2
# 17  345845                                    [Car, Car]             2
# 18  345846                                    [Car, Car]             2
# 19  345847                                  [Taxi, Taxi]             2
# 20  345848                                    [Car, Car]             2
# 21  345849        [LightGoodsVehicle, LightGoodsVehicle]             2
# 22  345850                                        [Taxi]             1
# 23  345851                                    [Car, Car]             2
# 24  345852                                    [Car, Car]             2
# 25  345853                                    [Car, Car]             2
# 26  345854                                    [Car, Car]             2
# 27  345855                                  [Taxi, Taxi]             2
# 28  345856                                    [Car, Car]             2
# 29  345857  [Motorcycle_125_500cc, Motorcycle_125_500cc]             2

# %%
df_vehicles =grouped_accidents

# %%
unique_types = set(vehicle for sublist in df_vehicles['type'] for vehicle in sublist)

print(len(unique_types))
unique_types
# Out:
# 15
# {'AgriculturalVehicle',
#  'BusOrCoach',
#  'Car',
#  'HeavyGoodsVehicle',
#  'LightGoodsVehicle',
#  'MediumGoodsVehicle',
#  'Minibus',
#  'Motorcycle_0_50cc',
#  'Motorcycle_125_500cc',
#  'Motorcycle_500cc_Plus',
#  'Motorcycle_50_125cc',
#  'OtherMotorVehicle',
#  'PedalCycle',
#  'RiddenHorse',
#  'Taxi'}

# %%
unique_types = set(vehicle for sublist in df_vehicles['type'] for vehicle in sublist)

print(len(unique_types))
unique_types
# Out:
# 15
# {'AgriculturalVehicle',
#  'BusOrCoach',
#  'Car',
#  'HeavyGoodsVehicle',
#  'LightGoodsVehicle',
#  'MediumGoodsVehicle',
#  'Minibus',
#  'Motorcycle_0_50cc',
#  'Motorcycle_125_500cc',
#  'Motorcycle_500cc_Plus',
#  'Motorcycle_50_125cc',
#  'OtherMotorVehicle',
#  'PedalCycle',
#  'RiddenHorse',
#  'Taxi'}

# %%
unique_lists = df_vehicles['type'].apply(tuple).unique()
print(len(unique_lists))
unique_lists
# Out:
# 89
# array([('Car', 'Car'), ('Car',), ('PedalCycle', 'PedalCycle'),
#        ('Car', 'Car', 'Car'), ('Taxi', 'Taxi', 'Taxi'), ('Taxi', 'Taxi'),
#        ('LightGoodsVehicle', 'LightGoodsVehicle'), ('Taxi',),
#        ('Motorcycle_125_500cc', 'Motorcycle_125_500cc'),
#        ('Motorcycle_50_125cc', 'Motorcycle_50_125cc'),
#        ('Motorcycle_50_125cc',), ('BusOrCoach', 'BusOrCoach'),
#        ('Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus'),
#        ('PedalCycle',), ('Motorcycle_125_500cc',),
#        ('Car', 'Car', 'Car', 'Car'), ('BusOrCoach',),
#        ('Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc'),
#        ('Motorcycle_125_500cc', 'Motorcycle_125_500cc', 'Motorcycle_125_500cc'),
#        ('OtherMotorVehicle',), ('LightGoodsVehicle',),
#        ('MediumGoodsVehicle', 'MediumGoodsVehicle'),
#        ('OtherMotorVehicle', 'OtherMotorVehicle'),
#        ('BusOrCoach', 'BusOrCoach', 'BusOrCoach'),
#        ('PedalCycle', 'PedalCycle', 'PedalCycle'),
#        ('PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle'),
#        ('Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus'),
#        ('Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc'),
#        ('HeavyGoodsVehicle',), ('HeavyGoodsVehicle', 'HeavyGoodsVehicle'),
#        ('Motorcycle_500cc_Plus',), ('Motorcycle_0_50cc',),
#        ('Motorcycle_0_50cc', 'Motorcycle_0_50cc'),
#        ('BusOrCoach', 'BusOrCoach', 'BusOrCoach', 'BusOrCoach', 'BusOrCoach', 'BusOrCoach', 'BusOrCoach'),
#        ('Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc'),
#        ('OtherMotorVehicle', 'OtherMotorVehicle', 'OtherMotorVehicle'),
#        ('Taxi', 'Taxi', 'Taxi', 'Taxi', 'Taxi', 'Taxi'),
#        ('LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle'),
#        ('Car', 'Car', 'Car', 'Car', 'Car'), ('Minibus', 'Minibus'),
#        ('MediumGoodsVehicle',),
#        ('HeavyGoodsVehicle', 'HeavyGoodsVehicle', 'HeavyGoodsVehicle'),
#        ('Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc'),
#        ('Taxi', 'Taxi', 'Taxi', 'Taxi', 'Taxi'),
#        ('Car', 'Car', 'Car', 'Car', 'Car', 'Car'), ('Minibus',),
#        ('LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle'),
#        ('Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc'),
#        ('BusOrCoach', 'BusOrCoach', 'BusOrCoach', 'BusOrCoach'),
#        ('Taxi', 'Taxi', 'Taxi', 'Taxi'),
#        ('Taxi', 'Taxi', 'Taxi', 'Taxi', 'Taxi', 'Taxi', 'Taxi'),
#        ('Motorcycle_125_500cc', 'Motorcycle_125_500cc', 'Motorcycle_125_500cc', 'Motorcycle_125_500cc'),
#        ('AgriculturalVehicle', 'AgriculturalVehicle'),
#        ('Car', 'Car', 'Car', 'Car', 'Car', 'Car', 'Car'),
#        ('Car', 'Car', 'Car', 'Car', 'Car', 'Car', 'Car', 'Car'),
#        ('LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle'),
#        ('Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus'),
#        ('PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle'),
#        ('LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle'),
#        ('Taxi', 'Taxi', 'Taxi', 'Taxi', 'Taxi', 'Taxi', 'Taxi', 'Taxi'),
#        ('MediumGoodsVehicle', 'MediumGoodsVehicle', 'MediumGoodsVehicle'),
#        ('OtherMotorVehicle', 'OtherMotorVehicle', 'OtherMotorVehicle', 'OtherMotorVehicle'),
#        ('PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle'),
#        ('Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc'),
#        ('Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc'),
#        ('Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc'),
#        ('HeavyGoodsVehicle', 'HeavyGoodsVehicle', 'HeavyGoodsVehicle', 'HeavyGoodsVehicle'),
#        ('PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle'),
#        ('Minibus', 'Minibus', 'Minibus', 'Minibus'),
#        ('AgriculturalVehicle', 'AgriculturalVehicle', 'AgriculturalVehicle'),
#        ('Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc'),
#        ('RiddenHorse', 'RiddenHorse'), ('Minibus', 'Minibus', 'Minibus'),
#        ('Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus'),
#        ('AgriculturalVehicle',),
#        ('MediumGoodsVehicle', 'MediumGoodsVehicle', 'MediumGoodsVehicle', 'MediumGoodsVehicle'),
#        ('Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc'),
#        ('RiddenHorse',),
#        ('OtherMotorVehicle', 'OtherMotorVehicle', 'OtherMotorVehicle', 'OtherMotorVehicle', 'OtherMotorVehicle', 'OtherMotorVehicle'),
#        ('LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle'),
#        ('RiddenHorse', 'RiddenHorse', 'RiddenHorse'),
#        ('OtherMotorVehicle', 'OtherMotorVehicle', 'OtherMotorVehicle', 'OtherMotorVehicle', 'OtherMotorVehicle'),
#        ('LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle', 'LightGoodsVehicle'),
#        ('Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc', 'Motorcycle_50_125cc'),
#        ('PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle', 'PedalCycle'),
#        ('Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus', 'Motorcycle_500cc_Plus'),
#        ('BusOrCoach', 'BusOrCoach', 'BusOrCoach', 'BusOrCoach', 'BusOrCoach', 'BusOrCoach'),
#        ('Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc', 'Motorcycle_0_50cc'),
#        ('BusOrCoach', 'BusOrCoach', 'BusOrCoach', 'BusOrCoach', 'BusOrCoach')],
#       dtype=object)

# %%
# Vehicle categories
categories = {
    "Motocycle": ["Motorcycle_0_50cc", "Motorcycle_50_125cc", "Motorcycle_125_500cc", "Motorcycle_500cc_Plus"],
    "Cart": ["Car", "Taxi", "Minibus", "LightGoodsVehicle"],
    "Heavy_Vehicles": ["BusOrCoach", "HeavyGoodsVehicle", "MediumGoodsVehicle"],
    "Pedalcycle": ["PedalCycle"],
}

category_lookup = {vehicle: category for category, vehicles in categories.items() for vehicle in vehicles}

def replace_with_category(vehicle_tuple):
    return tuple(category_lookup.get(vehicle, "Unknown") for vehicle in vehicle_tuple)

def is_mixed_category(vehicle_tuple):
    categories_in_tuple = set(replace_with_category(vehicle_tuple))
    return len(categories_in_tuple) > 1  # True if more than one category present

categorized_unique_lists = [replace_with_category(vehicle_tuple) for vehicle_tuple in unique_lists]

mixed_category_tuples = [vehicle_tuple for vehicle_tuple in unique_lists if is_mixed_category(vehicle_tuple)]

print("Categorized unique lists:", categorized_unique_lists)
print("Tuples with mixed categories (accidents between different vehicles):", mixed_category_tuples)
# Out:
# Categorized unique lists: [('Cart', 'Cart'), ('Cart',), ('Pedalcycle', 'Pedalcycle'), ('Cart', 'Cart', 'Cart'), ('Cart', 'Cart', 'Cart'), ('Cart', 'Cart'), ('Cart', 'Cart'), ('Cart',), ('Motocycle', 'Motocycle'), ('Motocycle', 'Motocycle'), ('Motocycle',), ('Heavy_Vehicles', 'Heavy_Vehicles'), ('Motocycle', 'Motocycle'), ('Pedalcycle',), ('Motocycle',), ('Cart', 'Cart', 'Cart', 'Cart'), ('Heavy_Vehicles',), ('Motocycle', 'Motocycle', 'Motocycle'), ('Motocycle', 'Motocycle', 'Motocycle'), ('Unknown',), ('Cart',), ('Heavy_Vehicles', 'Heavy_Vehicles'), ('Unknown', 'Unknown'), ('Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles'), ('Pedalcycle', 'Pedalcycle', 'Pedalcycle'), ('Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle'), ('Motocycle', 'Motocycle', 'Motocycle'), ('Motocycle', 'Motocycle', 'Motocycle'), ('Heavy_Vehicles',), ('Heavy_Vehicles', 'Heavy_Vehicles'), ('Motocycle',), ('Motocycle',), ('Motocycle', 'Motocycle'), ('Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Unknown', 'Unknown', 'Unknown'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Cart', 'Cart', 'Cart'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Cart', 'Cart'), ('Heavy_Vehicles',), ('Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Cart',), ('Cart', 'Cart', 'Cart', 'Cart'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles'), ('Cart', 'Cart', 'Cart', 'Cart'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Unknown', 'Unknown'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles'), ('Unknown', 'Unknown', 'Unknown', 'Unknown'), ('Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles'), ('Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle'), ('Cart', 'Cart', 'Cart', 'Cart'), ('Unknown', 'Unknown', 'Unknown'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Unknown', 'Unknown'), ('Cart', 'Cart', 'Cart'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Unknown',), ('Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles', 'Heavy_Vehicles'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Unknown',), ('Unknown', 'Unknown', 'Unknown', 'Unknown', 'Unknown', 'Unknown'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Unknown', 'Unknown', 'Unknown'), ('Unknown', 'Unknown', 'Unknown', 'Unknown', 'Unknown'), ('Cart', 'Cart', 'Cart', 'Cart', 'Cart', 'Cart'), ('Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle', 'Motocycle'), ('Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle', 'Pedalcycle'), ('Motocycle', 'Motocycle ...
# Tuples with mixed categories (accidents between different vehicles): []

# %%
categories = {
    "Motocycle": ["Motorcycle_0_50cc", "Motorcycle_50_125cc", "Motorcycle_125_500cc", "Motorcycle_500cc_Plus"],
    "Cart": ["Car", "Taxi", "Minibus", "LightGoodsVehicle"],
    "Heavy_Vehicles": ["BusOrCoach", "HeavyGoodsVehicle", "MediumGoodsVehicle"],
    "Pedalcycle": ["PedalCycle"],
}

def categorize_vehicle_type(vehicle_list):
    categorized = []
    for vehicle in vehicle_list:
        for category, types in categories.items():
            if vehicle in types:
                categorized.append(category)
                break
    return categorized

df_vehicles['categories'] = df_vehicles['type'].apply(categorize_vehicle_type)

unique_vehicle_types = set(vehicle for sublist in df_vehicles['type'] for vehicle in sublist)
print("Unique vehicle types in the dataset:", unique_vehicle_types)

category_counts = df_vehicles['categories'].explode().value_counts()

plt.figure(figsize=(8, 6))
category_counts.plot(kind='bar', color='skyblue', alpha=0.8)
plt.title('Histogram of Vehicle Categories')
plt.xlabel('Vehicle Category')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Unique vehicle types in the dataset: {'RiddenHorse', 'LightGoodsVehicle', 'Motorcycle_500cc_Plus', 'HeavyGoodsVehicle', 'BusOrCoach', 'Motorcycle_125_500cc', 'Motorcycle_0_50cc', 'MediumGoodsVehicle', 'Motorcycle_50_125cc', 'Car', 'Taxi', 'OtherMotorVehicle', 'Minibus', 'AgriculturalVehicle', 'PedalCycle'}

# %% [markdown]
# # NOTES SECTION
#
# ## 3 OPTIONS:
#
# * Forcasting
#  * Determine out of the dataset what would happen
#  * Predict accidents most likely
#  * we could use past year data and compare directly with more recent data
#
# * Corelating variables
#  * Finding relationship betweetn different variables
#  * expanding knowledge base to variables such as
#  * Street direction, speed limit, street light, roundabout presence
#  * tackle problems that normal statistics patterns or resarch can struggle with
#  * Anomaly detection
#
#
# * Optimization
#  * Optimize the dataset
#  * Most likely determining the best way to have the London transportation system
#  * A simulation, hard to determine results

# %% [markdown]
# We could study what subjects are more at risk of severe accidents
#
# What parts of the city are the most at risk
#
# For insurance purposes

# %% [markdown]
# IDEA:
# We could study the correlation between variables and accidents -> building a cost function to determine the reliability of a certain subject
# Could be useful for INSURANCE COMPANIES
